# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/reklama_sales.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x='TV', y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x='Radio', y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x='Newspaper', y='Sales')
plt.show()

# %%
df.corrwith(df['Sales']).sort_values(ascending=False)
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# dtype: float64

# %%
from sklearn import linear_model
LR_model = linear_model.LinearRegression()

x = np.asanyarray(df[['TV']])
y = np.asanyarray(df[['Sales']])

LR_model.fit(x, y)

theta1 = LR_model.coef_[0][0]
theta0 = LR_model.intercept_[0]
print(theta0)
print(theta1)
# Out:
# 6.974821488229891
# 0.055464770469558874

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x='TV', y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='TV', y='Sales')
plt.plot(x, theta0+theta1*x, '-r')
plt.show()

# %%
def linear(x):
    return theta0+theta1*x

# %%
df_new = df.sample(50)
df_new.drop(['Radio', 'Newspaper'], axis=1, inplace=True)
df_new
# Out:
#         TV  Sales
# 7    120.2   13.2
# 55   198.9   23.7
# 199  232.1   18.4
# 181  218.5   17.2
# 102  280.2   19.8
# 161   85.7   13.3
# 94   107.4   11.5
# 26   142.9   15.0
# 56     7.3    5.5
# 76    27.5    6.9
# 67   139.3   13.4
# 112  175.7   17.1
# 5      8.7    7.2
# 132    8.4    5.7
# 182   56.2    8.7
# 134   36.9   10.8
# 131  265.2   17.7
# 138   43.0    9.6
# 74   213.4   17.0
# 49    66.9    9.7
# 149   44.7   10.1
# 169  284.3   20.0
# 61   261.3   24.2
# 14   204.1   19.0
# 115   75.1   12.6
# 133  219.8   19.6
# 172   19.6    7.6
# 37    74.7   14.7
# 178  276.7   16.8
# 110  225.8   18.4
# 117   76.4    9.4
# 23   228.3   20.5
# 82    75.3   11.3
# 123  123.1   15.2
# 185  205.0   22.6
# 165  234.5   16.9
# 190   39.5   10.8
# 83    68.4   13.6
# 197  177.0   14.8
# 24    62.3    9.7
# 160  172.5   16.4
# 140   73.4   10.9
# 28   248.8   18.9
# 38    43.1   10.1
# 135   48.3   11.6
# 97   184.9   20.5
# 141  193.7   19.2
# 164  117.2   11.9
# 153  171.3   16.0
# ...

# %%
df_new['Sales_pred'] = linear(df['TV'])
df_new
# Out:
#         TV  Sales  Sales_pred
# 7    120.2   13.2   13.641687
# 55   198.9   23.7   18.006764
# 199  232.1   18.4   19.848195
# 181  218.5   17.2   19.093874
# 102  280.2   19.8   22.516050
# 161   85.7   13.3   11.728152
# 94   107.4   11.5   12.931738
# 26   142.9   15.0   14.900737
# 56     7.3    5.5    7.379714
# 76    27.5    6.9    8.500103
# 67   139.3   13.4   14.701064
# 112  175.7   17.1   16.719982
# 5      8.7    7.2    7.457365
# 132    8.4    5.7    7.440726
# 182   56.2    8.7   10.091942
# 134   36.9   10.8    9.021472
# 131  265.2   17.7   21.684079
# 138   43.0    9.6    9.359807
# 74   213.4   17.0   18.811004
# 49    66.9    9.7   10.685415
# 149   44.7   10.1    9.454097
# 169  284.3   20.0   22.743456
# 61   261.3   24.2   21.467766
# 14   204.1   19.0   18.295181
# 115   75.1   12.6   11.140226
# 133  219.8   19.6   19.165978
# 172   19.6    7.6    8.061931
# 37    74.7   14.7   11.118040
# 178  276.7   16.8   22.321923
# 110  225.8   18.4   19.498767
# ...

# %%
np.sqrt((1/df_new.shape[0])*((df_new['Sales_pred']-df_new['Sales'])**2).sum())
# Out:
# 2.1352886813869727
